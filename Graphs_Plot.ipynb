# %% [markdown]
# # Cancer Prediction Graphs Plots :-

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

# Step 1: Load Dataset
cancer = pd.read_csv('/content/Cancer.csv')

# Step 2: Data Preprocessing
X = cancer.drop(['id', 'diagnosis', 'Unnamed: 32'], axis=1)
y = cancer['diagnosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2529)

# Step 3: Train Logistic Regression Model
model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)

# Step 4: Predictions and Evaluation
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# Step 5: Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant'], yticklabels=['Benign', 'Malignant'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Step 6: Accuracy Visualization
labels = ['Correct Predictions', 'Incorrect Predictions']
values = [cm[0, 0] + cm[1, 1], cm[0, 1] + cm[1, 0]]
colors = ['#66b3ff', '#ff9999']

plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Model Prediction Accuracy')
plt.show()

# %%
# Step 7: Print Evaluation Metrics
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9590643274853801
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.98      0.95      0.97       102
#            M       0.93      0.97      0.95        69
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# #System Architecture

# %%
from graphviz import Digraph


dot = Digraph("Cancer Prediction System Architecture")


dot.node("1", "Data Layer\n- Input Dataset\n- Preprocessing", shape="box", style="rounded")
dot.node("2", "Processing Layer\n- Feature Extraction\n- Model Training", shape="box", style="rounded")
dot.node("3", "Prediction Layer\n- Model Deployment\n- Input Interface", shape="box", style="rounded")
dot.node("4", "Evaluation Layer\n- Metrics Calculation\n- Error Analysis", shape="box", style="rounded")
dot.node("5", "Visualization Layer\n- Graphs\n- Metrics Display", shape="box", style="rounded")
dot.node("6", "Presentation Layer\n- User Interface\n- Outputs", shape="box", style="rounded")
dot.node("7", "Deployment Layer\n- Cloud Hosting\n- Integration", shape="box", style="rounded")


dot.edge("1", "2", label="Processed Features")
dot.edge("2", "3", label="Trained Model")
dot.edge("3", "4", label="Predicted Results")
dot.edge("4", "5", label="Metrics")
dot.edge("5", "6", label="Graphs & Results")
dot.edge("3", "6", label="Prediction Output")
dot.edge("6", "7", label="Deployed System")
dot.edge("2", "7", label="Model Deployment")


dot.render("Cancer_Prediction_Architecture", format="png", cleanup=True)
dot.view()
# Out:
# 'Cancer_Prediction_Architecture.pdf'
